# %%
import pandas_datareader.data as pdr
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
from datetime import datetime
# %matplotlib inline

# %%
start = datetime(2021, 6, 1)
end = datetime(2022, 1, 1)

# %%
BTC = pdr.DataReader('BTC-USD','yahoo',start,end)
ETH = pdr.DataReader('ETH-USD','yahoo',start,end)
DOGE = pdr.DataReader('DOGE-USD','yahoo',start,end)
SHIB = pdr.DataReader('SHIB-USD','yahoo',start,end)

# %%
BTC
# Out:
#                     High           Low          Open         Close  \
# Date
# 2021-06-01  37896.734375  35787.085938  37293.792969  36684.925781
# 2021-06-02  38231.339844  35966.308594  36699.921875  37575.179688
# 2021-06-03  39478.953125  37243.972656  37599.410156  39208.765625
# 2021-06-04  39242.484375  35717.722656  39242.484375  36894.406250
# 2021-06-05  37917.714844  34900.414062  36880.156250  35551.957031
# ...                  ...           ...           ...           ...
# 2021-12-29  48119.742188  46201.496094  47623.871094  46444.710938
# 2021-12-30  47879.964844  46060.312500  46490.605469  47178.125000
# 2021-12-31  48472.527344  45819.953125  47169.371094  46306.445312
# 2022-01-01  47827.312500  46288.484375  46311.746094  47686.812500
# 2022-01-02  47881.406250  46856.937500  47680.925781  47345.218750
#
#                  Volume     Adj Close
# Date
# 2021-06-01  34639423297  36684.925781
# 2021-06-02  33070867190  37575.179688
# ...

# %%
tickers = ['BTC-USD','ETH-USD','DOGE-USD','SHIB-USD']

# %%
crypto = pd.concat([BTC,ETH,DOGE,SHIB],axis=1,keys=tickers)
crypto.head()
# Out:
#                  BTC-USD                                            \
#                     High           Low          Open         Close
# Date
# 2021-06-01  37896.734375  35787.085938  37293.792969  36684.925781
# 2021-06-02  38231.339844  35966.308594  36699.921875  37575.179688
# 2021-06-03  39478.953125  37243.972656  37599.410156  39208.765625
# 2021-06-04  39242.484375  35717.722656  39242.484375  36894.406250
# 2021-06-05  37917.714844  34900.414062  36880.156250  35551.957031
#
#                                            ETH-USD                            \
#                  Volume     Adj Close         High          Low         Open
# Date
# 2021-06-01  34639423297  36684.925781  2739.737549  2531.160645  2707.560547
# 2021-06-02  33070867190  37575.179688  2801.392334  2555.401367  2634.456055
# 2021-06-03  35460750427  39208.765625  2891.254883  2667.684326  2708.376221
# 2021-06-04  41831090187  36894.406250  2857.165527  2562.637451  2857.165527
# ...

# %%
crypto.columns.names = ['Crypto Ticker','Crypto Info']

# %%
crypto.head()
# Out:
# Crypto Ticker       BTC-USD                                            \
# Crypto Info            High           Low          Open         Close
# Date
# 2021-06-01     37896.734375  35787.085938  37293.792969  36684.925781
# 2021-06-02     38231.339844  35966.308594  36699.921875  37575.179688
# 2021-06-03     39478.953125  37243.972656  37599.410156  39208.765625
# 2021-06-04     39242.484375  35717.722656  39242.484375  36894.406250
# 2021-06-05     37917.714844  34900.414062  36880.156250  35551.957031
#
# Crypto Ticker                                 ETH-USD               \
# Crypto Info         Volume     Adj Close         High          Low
# Date
# 2021-06-01     34639423297  36684.925781  2739.737549  2531.160645
# 2021-06-02     33070867190  37575.179688  2801.392334  2555.401367
# 2021-06-03     35460750427  39208.765625  2891.254883  2667.684326
# 2021-06-04     41831090187  36894.406250  2857.165527  2562.637451
# ...

# %%
crypto.xs(key='Close',axis=1,level='Crypto Info').max()
# Out:
# Crypto Ticker
# BTC-USD     67566.828125
# ETH-USD      4812.087402
# DOGE-USD        0.423374
# SHIB-USD        0.000080
# dtype: float64

# %%
crypto.xs(key='Close',axis=1,level='Crypto Info').min()
# Out:
# Crypto Ticker
# BTC-USD     29807.347656
# ETH-USD      1787.510742
# DOGE-USD        0.157565
# SHIB-USD        0.000006
# dtype: float64

# %%
returns = pd.DataFrame()

# %%
for tick in tickers:
    returns[tick+' Return'] = crypto[tick]['Close'].pct_change()

# %%
returns.head()
# Out:
#             BTC-USD Return  ETH-USD Return  DOGE-USD Return  SHIB-USD Return
# Date
# 2021-06-01             NaN             NaN              NaN              NaN
# 2021-06-02        0.024268        0.027570         0.144016         0.000000
# 2021-06-03        0.043475        0.055061        -0.055296         0.111111
# 2021-06-04       -0.059027       -0.058467        -0.059105        -0.100000
# 2021-06-05       -0.036386       -0.021434        -0.011017        -0.111111

# %%
sns.pairplot(returns[1:])

# %%
returns.idxmin()
# Out:
# BTC-USD Return    2021-06-21
# ETH-USD Return    2021-06-21
# DOGE-USD Return   2021-06-21
# SHIB-USD Return   2021-06-21
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BTC-USD Return    2021-06-09
# ETH-USD Return    2021-09-01
# DOGE-USD Return   2021-08-07
# SHIB-USD Return   2021-10-27
# dtype: datetime64[ns]

# %%
returns.std()
# Out:
# BTC-USD Return     0.036621
# ETH-USD Return     0.043898
# DOGE-USD Return    0.061184
# SHIB-USD Return    0.112768
# dtype: float64

# %%
sns.displot(returns['SHIB-USD Return'],color='orange',bins=20)

# %%
sns.displot(returns['BTC-USD Return'],color='yellow',bins=20)

# %%
for tick in tickers:
    crypto[tick]['Close'].plot(label=tick,figsize=(12,4))
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_5/xkxy9xsx3953dnfvbgz4bly00000gn/T/ipykernel_978/3577900653.py in <module>
#       1 for tick in tickers:
#       2     crypto[tick]['Close'].plot(label=tick,figsize=(12,4))
# ----> 3 plt.legend()
#
# NameError: name 'plt' is not defined
